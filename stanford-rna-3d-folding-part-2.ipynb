# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score

# %% [markdown]
# **help uncover how RNA molecules fold and function at the molecular level by developing machine learning models that predict the 3D structure of RNA molecules using only their sequences.**

# %%
data=pd.read_csv("/kaggle/input/stanford-rna-3d-folding-2/train_sequences.csv")
data
# Out:
#      target_id                                           sequence  \
# 0         4TNA  GCGGAUUUAGCUCAGUUGGGAGAGCGCCAGACUGAAGAUCUGGAGG...
# 1         6TNA  GCGGAUUUAGCUCAGUUGGGAGAGCGCCAGACUGAAGAUCUGGAGG...
# 2         1TRA  GCGGAUUUAGCUCAGUUGGGAGAGCGCCAGACUGAAGAUCUGGAGG...
# 3         1TN2  GCGGAUUUAGCUCAGUUGGGAGAGCGCCAGACUGAAGAUCUGGAGG...
# 4         1TN1  GCGGAUUUAGCUCAGUUGGGAGAGCGCCAGACUGAAGAUCUGGAGG...
# ...        ...                                                ...
# 5711      9HLZ  GUAAAAAAUUUAUAAGAAUAUGAUGUUGGUUCAGAUUAAGCGCUAA...
# 5712      9HM0  GUAAAAAAUUUAUAAGAAUAUGAUGUUGGUUCAGAUUAAGCGCUAA...
# 5713      9HM4  AAUCCCAUCACCAUCUUCCAGGAGCGAGAUCCCUCCAAAAUCGGGG...
# 5714      9I1W  AAACUUUCAACAACGGAUCUCUUGGUUCUGGCAUCGAUGAAGAACG...
# 5715      9QCC  AUUGUACACGGCCGAAUAUUGUACACGGCCGAAUAUUGUACACGGC...
#
#      temporal_cutoff                                        description  \
# 0         1978-04-12  FURTHER REFINEMENT OF THE STRUCTURE OF YEAST T...
# ...

# %%
data.isnull().sum()
# Out:
# target_id             0
# sequence              0
# temporal_cutoff       0
# description           0
# stoichiometry         0
# all_sequences         0
# ligand_ids         1868
# ligand_SMILES      1855
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5716 entries, 0 to 5715
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   target_id        5716 non-null   object
#  1   sequence         5716 non-null   object
#  2   temporal_cutoff  5716 non-null   object
#  3   description      5716 non-null   object
#  4   stoichiometry    5716 non-null   object
#  5   all_sequences    5716 non-null   object
#  6   ligand_ids       3848 non-null   object
#  7   ligand_SMILES    3861 non-null   object
# dtypes: object(8)
# memory usage: 357.4+ KB
