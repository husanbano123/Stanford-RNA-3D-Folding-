# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/rental-product-recommendation-system/new_site_products.csv
# /kaggle/input/rental-product-recommendation-system/new_site_orders.csv
# /kaggle/input/rental-product-recommendation-system/old_site_new_site_products.csv
# /kaggle/input/rental-product-recommendation-system/old_site_carts.csv
# /kaggle/input/rental-product-recommendation-system/old_site_orders.csv
# /kaggle/input/rental-product-recommendation-system/metrika_hits.csv
# /kaggle/input/rental-product-recommendation-system/metrika_visits_test.csv
# /kaggle/input/rental-product-recommendation-system/metrika_hits_test.csv
# /kaggle/input/rental-product-recommendation-system/metrika_visits.csv
# /kaggle/input/rental-product-recommendation-system/old_site_products.csv

# %% [markdown]
# # **Goal :**

# %% [markdown]
# To build a model that, given the metadata of a browsing session and the sequence of visited pages, predicts which product pages the user will visit next.
#
# 🛒 A recommendation engine for an e-commerce rental site
#
# User clicked products in a session →
# Predict next products they will visit →
# Top 6 products

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 📦 Role of Each Dataset
#
# | Type                        | Dataset                      | What it Contains                                              | How It’s Used in the Project                               |
# | --------------------------- | ---------------------------- | ------------------------------------------------------------- | ---------------------------------------------------------- |
# | 👤 **User Browsing**        | `metrika_hits`               | Page views, product clicks, device & traffic data             | Build user activity sequences, understand product interest |
# | 🧭 **Session Info**         | `metrika_visits`             | Session-level metadata (new user, traffic source, device)     | Create session features and user context                   |
# | 🛍️ **Product Info**        | `new_site_products`          | Product categories, brand, price, attributes, age suitability | Build item features for content-based & hybrid models      |
# | 🔥 **Popularity**           | `new_site_orders`            | Purchase history, product demand, revenue                     | Calculate product popularity, trending items               |
# | 🧠 **High Intent Behavior** | `old_site_carts`             | Cart additions, near-purchase actions                         | Strong purchase intent signals                             |
# | 📈 **Extra Behavior**       | `old_site_orders`            | Historical purchase patterns                                  | Learn long-term user preferences                           |
# | 🧩 **Similarity Learning**  | `old_site_products`          | Old catalog product attributes                                | Build item similarity embeddings                           |
# | 🔗 **ID Bridge**            | `old_site_new_site_products` | Mapping old product IDs to new ones                           | Merge old & new product history                            |

# %%
metrika_hits=pd.read_csv("/kaggle/input/rental-product-recommendation-system/metrika_hits.csv")
metrika_hits_test=pd.read_csv("/kaggle/input/rental-product-recommendation-system/metrika_hits_test.csv")
metrika_visits=pd.read_csv("/kaggle/input/rental-product-recommendation-system/metrika_visits.csv")
metrika_visits_test=pd.read_csv("/kaggle/input/rental-product-recommendation-system/metrika_visits_test.csv")
new_site_orders=pd.read_csv("/kaggle/input/rental-product-recommendation-system/new_site_orders.csv")
new_site_products=pd.read_csv("/kaggle/input/rental-product-recommendation-system/new_site_products.csv")
old_site_carts=pd.read_csv("/kaggle/input/rental-product-recommendation-system/old_site_carts.csv")
old_site_new_site_product=pd.read_csv("/kaggle/input/rental-product-recommendation-system/old_site_new_site_products.csv")
old_site_orders=pd.read_csv("/kaggle/input/rental-product-recommendation-system/old_site_orders.csv")
old_site_products=pd.read_csv("/kaggle/input/rental-product-recommendation-system/old_site_products.csv")
# Out:
# /tmp/ipykernel_17/4186222877.py:1: DtypeWarning: Columns (1,3,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   metrika_hits=pd.read_csv("/kaggle/input/rental-product-recommendation-system/metrika_hits.csv")
# /tmp/ipykernel_17/4186222877.py:3: DtypeWarning: Columns (1,4,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   metrika_visits=pd.read_csv("/kaggle/input/rental-product-recommendation-system/metrika_visits.csv")

# %%
print("Metrika hits",metrika_hits.shape)
print("Metrika hits test",metrika_hits_test.shape)
print("Metrika visit",metrika_visits.shape)
print("Metrika visit test",metrika_visits_test.shape)
print("new site orders",new_site_orders.shape)
print("new site products",new_site_products.shape)
print("old site carts",old_site_carts.shape)
print("old site  new site products",old_site_new_site_product.shape)
print("old site orders",old_site_orders.shape)
print("old site products",old_site_products.shape)
# Out:
# Metrika hits (1757619, 31)
# Metrika hits test (6880, 31)
# Metrika visit (345214, 24)
# Metrika visit test (1363, 24)
# new site orders (2857, 21)
# new site products (688, 97)
# old site carts (20839, 13)
# old site  new site products (464, 2)
# old site orders (17905, 15)
# old site products (761, 74)

# %%
print("Metrika hits",metrika_hits.columns)

print("Metrika visit",metrika_visits.columns)

print("new site orders",new_site_orders.columns)
print("new site products",new_site_products.columns)
print("old site carts",old_site_carts.columns)
print("old site  new site products",old_site_new_site_product.columns)
print("old site orders",old_site_orders.columns)
print("old site products",old_site_products.columns)
# Out:
# Metrika hits Index(['project_id', 'watch_id', 'date_time', 'client_id', 'region_country',
#        'region_city', 'url', 'page_type', 'slug', 'artificial', 'is_page_view',
#        'not_bounce', 'link', 'download', 'last_traffic_source',
#        'last_search_engine_root', 'last_search_engine', 'last_adv_engine',
#        'last_social_network', 'last_social_network_profile',
#        'recommendation_system', 'messenger', 'device_category', 'mobile_phone',
#        'mobile_phone_model', 'operating_system_root', 'operating_system',
#        'browser', 'browser_major_version', 'screen_width', 'screen_height'],
#       dtype='object')
# Metrika visit Index(['project_id', 'visit_id', 'date_time', 'is_new_user', 'client_id',
#        'region_country', 'region_city', 'watch_ids', 'traffic_source',
#        'adv_engine', 'search_engine_root', 'search_engine', 'social_network',
#        'recommendation_system', 'messenger', 'device_category', 'mobile_phone',
#        'mobile_phone_model', 'operating_system_root', 'operating_system',
#        'browser', 'browser_major_version', 'screen_width', 'screen_height'],
#       dtype='object')
# new site orders Index(['id', 'number', 'user_id', 'create_date', 'start_date', 'end_date',
#        'rental_days', 'status_code', 'total_amount', 'rental_amount',
#        'promo_discount_percent', 'discount_amount', 'shipping_type',
#        'shipping_amount', 'return_amount', 'source_type', 'product_id',
#        'product_price', 'product_discount_amount', 'color', 'modified_on'],
#       dtype='object')
# new site products Index(['id', 'name', 'brand', 'main_category', 'categories',
#        'site_category_paths', 'color', 'price_per_period_day',
#        'price_per_period2days', 'price_per_period3days',
#        'price_per_period5days', 'price_per_period_week',
#        'price_per_period2weeks', 'price_per_period3weeks',
#        'price_per_period4weeks', 'price_per_period8weeks',
#        'price_per_period12weeks', 'price_sell', 'description',
#        'description_additional', 'weight', 'size', 'slug',
#        'age_zero_six_month', 'age_six_twelve_month', 'age_one_two_years',
#        'age_two_three_years', 'age_three_four_years', 'age_four_five_years',
#        'age_six_plus_years', 'param_label', 'param_country_of_origin',
#        'param_weight_without_package', 'param_car_seat_mount', 'param_type',
#        'param_composition', 'param_category', 'param_age',
#        'param_child_weight', 'param_color', 'param_backrest_positions',
#        'param_has_mobile', 'param_power_supply', 'param_installation_method',
#        'param_car_seat_carrier', 'param_mount_type', 'param_weight_param',
#        'param_height_measurement', 'param_operating_range',
#        'param_night_vision', 'param_thermometer', 'param_voice_activation',
#        'param_educational_elements', 'param_melodies', 'param_bumpers',
#        'param_size_param', 'param_carrying_method',
#        'param_height_positions_count', 'param_features',
#        'param_height_positions_number', 'param_backrest_tilt_positions_number',
#        'param_adjustment', 'param_child_height', 'param_seat_height',
#        'param_handlebar_height', 'param_backrest_height',
#        'param_rocking_direction', 'param_development_functions',
#        'param_skills_developed', 'param_themes', 'param_material',
#        'param_effects', 'param_height', 'param_diameter', 'param_depth',
#        'param_balls_count', 'param_width', 'param_max_load',
#        'param_safety_net_height', 'param_safety', 'param_volume',
#        'param_measurement_accuracy', 'param_levels_count',
#        'param_backrest_tilt_adjustment', 'param_backrest_tilt',
#        'param_sleeping_area_size', 'param_package_contents',
#        'param_measurement_step', 'param_folded_size', 'param_unfolded_size',
#        'param_backrest_height_adjustment', 'param_table_positions',
#        'param_footrest_positions', 'param_footrest_adjustment',
#        'param_slide_length', 'param_melodies_count',
#        'param_vk_product_category'],
#       dtype='object')
# old site carts Index(['id', 'user_id', 'order_id', 'rental_days', 'promo_discount_percent',
#        'delivery_date', 'modified_on', 'cart_item_id', 'cart_item_deleted',
#        'product_id', 'cart_item_price', 'cart_item_order_id',
#        'cart_item_modified_on'],
#       dtype='object')
# old site  new site products Index(['old_site_id', 'new_site_id'], dtype='object')
# old site orders Index(['id', 'user_id', 'create_date', 'start_date', 'end_date', 'rental_days',
#        'status_code', 'rental_amount', 'promo_discount_percent',
#        'shipping_type', 'shipping_amount', 'return_amount', 'source_type',
#        'product_id', 'modified_on'],
#       dtype='object')
# old site products Index(['id', 'name', 'brand', 'main_category', 'categories',
#        'price_per_period3days', 'price_per_period_week',
#        'price_per_period_month', 'partner_id', 'description', 'weight', 'size',
#        'slug', 'age_zero_six_month', 'age_six_twelve_month',
#        'age_one_two_years', 'age_two_three_years', 'age_three_four_years',
#        'age_four_five_years', 'age_six_plus_years', 'param_child_weight',
#        'param_group', 'param_material', 'param_safety_standards',
#        'param_mount_type', 'param_seat_type', 'param_installation',
#        'param_child_fixation', 'param_additional_functions',
#        'param_configuration', 'param_features', 'param_speed_count',
#        'param_max_load', 'param_operating_principle', 'param_rocking_modes',
#        'param_seat_belts', 'param_max_child_weight',
#        'param_backrest_sleeping_positions', 'param_stroller_type',
#        'param_accessories', 'param_price_range', 'param_wheel_type',
#        'param_wheel_count', 'param_type', 'param_foreign_languages',
#        'param_melodies_and_sounds', 'param_volume_levels',
#        'param_elements_count', 'param_toy_type', 'param_functions',
#        'param_arc_count', 'param_child_unit_power',
#        'param_child_unit_functions', 'param_parent_unit_functions',
#        'param_roleplay_toy_type', 'param_discreteness', 'param_shape',
#        'param_param_weight', 'param_bike_seat_mount', 'param_kind',
#        'param_mount', 'param_melodies', 'param_melody_count',
#        'param_hanging_toy_count', 'param_chair_type', 'param_child_positions',
#        'param_carrying_method', 'param_table_type', 'param_mobility',
#        'param_adjustment', 'param_water_tank_volume', 'param_other',
#        'param_screen_diagonal', 'param_parent_unit_power'],
#       dtype='object')

# %%
new_site_products
# Out:
#              id                                               name  \
# 0     463480210  Кокон для новорожденных Cocoonababy Red Castle...
# 1     463480211  Кокон для новорожденных Matello Cocon Baby Lux...
# 2     463480212  Кокон-люлька для новорожденных Farla Baby Shel...
# 3     463480213          Качели-шезлонг 4moms MamaRoo 4.0 напрокат
# 4     463480214          Качели-шезлонг 4moms MamaRoo 3.0 напрокат
# ..          ...                                                ...
# 683  1651502137                       Адаптеры для автолюльки Yoyo
# 684  1655011689    Электрокачели MamaRoo NEW + весы Maman напрокат
# 685  1677458905                      Обезьянка на кольцах напрокат
# 686  1677460825    Развивающая игрушка "Маленькие друзья" напрокат
# 687  1678176625                       Манеж-кровать Зебра напрокат
#
#              brand             main_category  \
# 0       Red Castle  Коконы для новорожденных
# 1          Matello  Коконы для новорожденных
# 2            Farla  Коконы для новорожденных
# 3            4moms             Электрокачели
# 4            4moms             Электрокачели
# ..             ...                       ...
# 683        BabyZen                   Коляски
# 684   Maman##4moms              Акции недели
# 685  Bright Starts       Музыкальные игрушки
# 686   Fisher-Price       Музыкальные игрушки
# 687      Coto Baby          Кроватки, манежи
#
#                                         categories  \
# 0                     ["Коконы для новорожденных"]
# 1                     ["Коконы для новорожденных"]
# 2                     ["Коконы для новорожденных"]
# 3             ["Качели, шезлонги","Электрокачели"]
# 4             ["Качели, шезлонги","Электрокачели"]
# ..                                             ...
# 683                                    ["Коляски"]
# 684     ["Акции недели","Качели, шезлонги","Весы"]
# 685  ["Развивающие игрушки","Музыкальные игрушки"]
# 686  ["Развивающие игрушки","Музыкальные игрушки"]
# 687                           ["Кроватки, манежи"]
#
#                                    site_category_paths color  \
# 0    Все товары ## Все товары/Товары для новорожден...   NaN
# 1    Все товары ## Все товары/Коконы для новорожденных   NaN
# 2    Все товары ## Все товары/Товары для новорожден...   NaN
# 3    Все товары ## Все товары/Товары для новорожден...   NaN
# 4    Все товары ## Все товары/Качели, шезлонги ## В...   NaN
# ..                                                 ...   ...
# 683  Все товары/Коляски ## Все товары/Коляски/Аксес...   NaN
# 684  Все товары ## Все товары/Акции недели ## Все т...   NaN
# 685  Все товары ## Все товары/Развивающие игрушки #...   NaN
# 686  Все товары ## Все товары/Развивающие игрушки #...   NaN
# 687  Все товары ## Все товары/Кроватки, манежи ## В...   NaN
#
#      price_per_period_day  price_per_period2days  price_per_period3days  ...  \
# 0                     NaN                    NaN                    NaN  ...
# 1                     NaN                    NaN                    NaN  ...
# 2                     NaN                    NaN                    NaN  ...
# 3                     NaN                    NaN                    NaN  ...
# 4                     NaN                    NaN                    NaN  ...
# ..                    ...                    ...                    ...  ...
# 683                   NaN                    NaN                    NaN  ...
# 684                   NaN                    NaN                    NaN  ...
# 685                   NaN                    NaN                    NaN  ...
# 686                   NaN                    NaN                    NaN  ...
# 687                   NaN                    NaN                    NaN  ...
#
#      param_measurement_step  param_folded_size  param_unfolded_size  \
# 0                        []                 []                   []
# 1                        []                 []                   []
# 2                        []                 []                   []
# 3                        []                 []                   []
# 4                        []                 []                   []
# ..                      ...                ...                  ...
# 683                      []                 []                   []
# 684                      []                 []                   []
# 685                      []                 []                   []
# 686                      []                 []                   []
# 687                      []                 []                   []
#
#      param_backrest_height_adjustment  param_table_positions  \
# 0                                  []                     []
# 1                                  []                     []
# 2                                  []                     []
# 3                                  []                     []
# 4                                  []                     []
# ..                                ...                    ...
# 683                                []                     []
# 684                                []                     []
# 685                                []                     []
# 686                                []                     []
# 687                                []                     []
#
#      param_footrest_positions  param_footrest_adjustment  param_slide_length  \
# 0                          []                         []                  []
# 1                          []                         []                  []
# 2                          []                         []                  []
# 3                          []                         []                  []
# 4                          []                         []                  []
# ..                        ...                        ...                 ...
# 683                        []                         []                  []
# 684                        []                         []                  []
# 685                        []                         []                  []
# 686                        []                         []                  []
# 687                        []                         []                  []
#
#     param_melodies_count           param_vk_product_category
# 0                     []  ["Детские товары/Детские коляски"]
# 1                     []  ["Детские товары/Детские коляски"]
# 2                     []  ["Детские товары/Детские коляски"]
# 3                     []  ["Детские товары/Детские коляски"]
# 4                     []  ["Детские товары/Детские коляски"]
# ..                   ...                                 ...
# 683                   []                                  []
# 684                   []                                  []
# 685                   []                                  []
# 686                   []                                  []
# 687                   []                                  []
#
# [688 rows x 97 columns]

# %%
metrika_hits
# Out:
#          project_id             watch_id            date_time  \
# 0                 1  8194662451870622352  2021-11-24T00:06:51
# 1                 1  7945031156395861140  2021-11-24T00:09:06
# 2                 1  6365098314568244974  2021-11-24T00:09:07
# 3                 1  5280229437160873424  2021-11-24T00:09:21
# 4                 1   133574988465249163  2021-11-24T00:09:52
# ...             ...                  ...                  ...
# 1757614           0  2825584559588331111  2025-10-14T23:53:35
# 1757615           0  5093067904021115436  2025-10-14T23:53:35
# 1757616           0  5531199914965553706  2025-10-14T23:53:35
# 1757617           0  4996877742628913121  2025-10-14T23:53:36
# 1757618           0  2743778207496987573  2025-10-14T23:53:50
#
#                     client_id region_country       region_city  \
# 0         0203466395347938108         Russia            Moscow
# 1        98977237931745921755         Russia               NaN
# 2        98977237931745921755         Russia               NaN
# 3        98977237931745921755         Russia               NaN
# 4         1507358969798591332         Russia  Saint Petersburg
# ...                       ...            ...               ...
# 1757614   9910101217269060972         Russia            Moscow
# 1757615   9910101217269060972         Russia            Moscow
# 1757616   9910101217269060972         Russia            Moscow
# 1757617   9910101217269060972         Russia            Moscow
# 1757618   9910101217269060972         Russia            Moscow
#
#                                                        url page_type  \
# 0        https://oldsite.info/igrovoy-derevyannyy-stoli...   PRODUCT
# 1        https://oldsite.info/?fbclid=PAAabmh91Sd00ZtFJ...      MAIN
# 2        https://oldsite.info/?fbclid=PAAabmh91Sd00ZtFJ...      MAIN
# 3        https://oldsite.info/?fbclid=PAAabmh91Sd00ZtFJ...      MAIN
# 4                                    https://oldsite.info/      MAIN
# ...                                                    ...       ...
# 1757614           https://newsite.info/collection/kolyaski  CATEGORY
# 1757615           https://newsite.info/collection/kolyaski  CATEGORY
# 1757616           https://newsite.info/collection/kolyaski  CATEGORY
# 1757617           https://newsite.info/collection/kolyaski  CATEGORY
# 1757618           https://newsite.info/collection/kolyaski  CATEGORY
#
#                                            slug  artificial  ...  messenger  \
# 0        igrovoy-derevyannyy-stolik-elc-bolshoy           0  ...        NaN
# 1                                           NaN           0  ...        NaN
# 2                                           NaN           1  ...        NaN
# 3                                           NaN           1  ...        NaN
# 4                                           NaN           1  ...        NaN
# ...                                         ...         ...  ...        ...
# 1757614                                kolyaski           1  ...        NaN
# 1757615                                kolyaski           0  ...        NaN
# 1757616                                kolyaski           1  ...        NaN
# 1757617                                kolyaski           1  ...        NaN
# 1757618                                kolyaski           1  ...        NaN
#
#          device_category  mobile_phone  mobile_phone_model  \
# 0                      2        xiaomi               MI 11
# 1                      2          oppo             CPH1803
# 2                      2          oppo             CPH1803
# 3                      2          oppo             CPH1803
# 4                      1           NaN                 NaN
# ...                  ...           ...                 ...
# 1757614                2         apple              iPhone
# 1757615                2         apple              iPhone
# 1757616                2         apple              iPhone
# 1757617                2         apple              iPhone
# 1757618                2         apple              iPhone
#
#         operating_system_root operating_system          browser  \
# 0                     android       android_11     chromemobile
# 1                     android   android_oreo81  android_browser
# 2                     android   android_oreo81  android_browser
# 3                     android   android_oreo81  android_browser
# 4                   gnu_linux            linux           chrome
# ...                       ...              ...              ...
# 1757614            ios_double            ios18    safari_mobile
# 1757615            ios_double            ios18    safari_mobile
# 1757616            ios_double            ios18    safari_mobile
# 1757617            ios_double            ios18    safari_mobile
# 1757618            ios_double            ios18    safari_mobile
#
#         browser_major_version screen_width screen_height
# 0                          96          412           915
# 1                           8          360           760
# 2                           8          360           760
# 3                           8          360           760
# 4                          95         1920          1080
# ...                       ...          ...           ...
# 1757614                    18          440           956
# 1757615                    18          440           956
# 1757616                    18          440           956
# 1757617                    18          440           956
# 1757618                    18          440           956
#
# [1757619 rows x 31 columns]

# %% [markdown]
# **Feautre Blocks**
#
# | Component             | Comes From                                       |
# | --------------------- | ------------------------------------------------ |
# | **User behavior**     | metrika_hits, metrika_visits                     |
# | **Product knowledge** | new_site_products, old_site_products             |
# | **Purchase intent**   | new_site_orders, old_site_orders, old_site_carts |

# %% [markdown]
# **We combine these → create features → train ranking model.**

# %% [markdown]
# # **Step 1 : Prepare Behavior Data**

# %%
hits=pd.read_csv("/kaggle/input/rental-product-recommendation-system/metrika_hits.csv")
visit=pd.read_csv("/kaggle/input/rental-product-recommendation-system/metrika_visits.csv")
products=pd.read_csv("/kaggle/input/rental-product-recommendation-system/new_site_products.csv")
orders=pd.read_csv("/kaggle/input/rental-product-recommendation-system/new_site_orders.csv")
# Out:
# /tmp/ipykernel_17/1060669359.py:1: DtypeWarning: Columns (1,3,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   hits=pd.read_csv("/kaggle/input/rental-product-recommendation-system/metrika_hits.csv")
# /tmp/ipykernel_17/1060669359.py:2: DtypeWarning: Columns (1,4,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   visit=pd.read_csv("/kaggle/input/rental-product-recommendation-system/metrika_visits.csv")

# %% [markdown]
# # **Step 2 : Build USER SESSIONS (Behavior Base)**
#
# Goal: Understand what each user looked at.

# %%
hits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1757619 entries, 0 to 1757618
# Data columns (total 31 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   project_id                   int64
#  1   watch_id                     object
#  2   date_time                    object
#  3   client_id                    object
#  4   region_country               object
#  5   region_city                  object
#  6   url                          object
#  7   page_type                    object
#  8   slug                         object
#  9   artificial                   int64
#  10  is_page_view                 int64
#  11  not_bounce                   int64
#  12  link                         int64
#  13  download                     int64
#  14  last_traffic_source          object
#  15  last_search_engine_root      object
#  16  last_search_engine           object
#  17  last_adv_engine              object
#  18  last_social_network          object
#  19  last_social_network_profile  object
#  20  recommendation_system        object
#  21  messenger                    object
#  22  device_category              int64
#  23  mobile_phone                 object
#  24  mobile_phone_model           object
#  25  operating_system_root        object
#  26  operating_system             object
#  27  browser                      object
#  28  browser_major_version        int64
#  29  screen_width                 int64
#  30  screen_height                int64
# dtypes: int64(10), object(21)
# memory usage: 415.7+ MB

# %%
hits
# Out:
#          project_id             watch_id            date_time  \
# 0                 1  8194662451870622352  2021-11-24T00:06:51
# 1                 1  7945031156395861140  2021-11-24T00:09:06
# 2                 1  6365098314568244974  2021-11-24T00:09:07
# 3                 1  5280229437160873424  2021-11-24T00:09:21
# 4                 1   133574988465249163  2021-11-24T00:09:52
# ...             ...                  ...                  ...
# 1757614           0  2825584559588331111  2025-10-14T23:53:35
# 1757615           0  5093067904021115436  2025-10-14T23:53:35
# 1757616           0  5531199914965553706  2025-10-14T23:53:35
# 1757617           0  4996877742628913121  2025-10-14T23:53:36
# 1757618           0  2743778207496987573  2025-10-14T23:53:50
#
#                     client_id region_country       region_city  \
# 0         0203466395347938108         Russia            Moscow
# 1        98977237931745921755         Russia               NaN
# 2        98977237931745921755         Russia               NaN
# 3        98977237931745921755         Russia               NaN
# 4         1507358969798591332         Russia  Saint Petersburg
# ...                       ...            ...               ...
# 1757614   9910101217269060972         Russia            Moscow
# 1757615   9910101217269060972         Russia            Moscow
# 1757616   9910101217269060972         Russia            Moscow
# 1757617   9910101217269060972         Russia            Moscow
# 1757618   9910101217269060972         Russia            Moscow
#
#                                                        url page_type  \
# 0        https://oldsite.info/igrovoy-derevyannyy-stoli...   PRODUCT
# 1        https://oldsite.info/?fbclid=PAAabmh91Sd00ZtFJ...      MAIN
# 2        https://oldsite.info/?fbclid=PAAabmh91Sd00ZtFJ...      MAIN
# 3        https://oldsite.info/?fbclid=PAAabmh91Sd00ZtFJ...      MAIN
# 4                                    https://oldsite.info/      MAIN
# ...                                                    ...       ...
# 1757614           https://newsite.info/collection/kolyaski  CATEGORY
# 1757615           https://newsite.info/collection/kolyaski  CATEGORY
# 1757616           https://newsite.info/collection/kolyaski  CATEGORY
# 1757617           https://newsite.info/collection/kolyaski  CATEGORY
# 1757618           https://newsite.info/collection/kolyaski  CATEGORY
#
#                                            slug  artificial  ...  messenger  \
# 0        igrovoy-derevyannyy-stolik-elc-bolshoy           0  ...        NaN
# 1                                           NaN           0  ...        NaN
# 2                                           NaN           1  ...        NaN
# 3                                           NaN           1  ...        NaN
# 4                                           NaN           1  ...        NaN
# ...                                         ...         ...  ...        ...
# 1757614                                kolyaski           1  ...        NaN
# 1757615                                kolyaski           0  ...        NaN
# 1757616                                kolyaski           1  ...        NaN
# 1757617                                kolyaski           1  ...        NaN
# 1757618                                kolyaski           1  ...        NaN
#
#          device_category  mobile_phone  mobile_phone_model  \
# 0                      2        xiaomi               MI 11
# 1                      2          oppo             CPH1803
# 2                      2          oppo             CPH1803
# 3                      2          oppo             CPH1803
# 4                      1           NaN                 NaN
# ...                  ...           ...                 ...
# 1757614                2         apple              iPhone
# 1757615                2         apple              iPhone
# 1757616                2         apple              iPhone
# 1757617                2         apple              iPhone
# 1757618                2         apple              iPhone
#
#         operating_system_root operating_system          browser  \
# 0                     android       android_11     chromemobile
# 1                     android   android_oreo81  android_browser
# 2                     android   android_oreo81  android_browser
# 3                     android   android_oreo81  android_browser
# 4                   gnu_linux            linux           chrome
# ...                       ...              ...              ...
# 1757614            ios_double            ios18    safari_mobile
# 1757615            ios_double            ios18    safari_mobile
# 1757616            ios_double            ios18    safari_mobile
# 1757617            ios_double            ios18    safari_mobile
# 1757618            ios_double            ios18    safari_mobile
#
#         browser_major_version screen_width screen_height
# 0                          96          412           915
# 1                           8          360           760
# 2                           8          360           760
# 3                           8          360           760
# 4                          95         1920          1080
# ...                       ...          ...           ...
# 1757614                    18          440           956
# 1757615                    18          440           956
# 1757616                    18          440           956
# 1757617                    18          440           956
# 1757618                    18          440           956
#
# [1757619 rows x 31 columns]

# %%
hits['date_time'] = pd.to_datetime(hits['date_time'],format='mixed',errors='coerce')
hits = hits.sort_values(['client_id','date_time'])

# %%
hits=hits.dropna(subset=['date_time'])
hits.head()
# Out:
#          project_id             watch_id           date_time client_id  \
# 1359682           0  7974165888557582235 2025-04-11 08:53:37         8
# 1368594           0  5392466718857393154 2025-04-20 15:26:19         8
# 1370087           0  2717532802682868090 2025-04-22 10:17:55         8
# 1373161           0  6099345943357788389 2025-04-24 21:30:44         8
# 1373660           0  8410812400479315010 2025-04-25 13:13:32         8
#
#         region_country       region_city                    url page_type  \
# 1359682         Russia        Domodedovo  https://newsite.info/      MAIN
# 1368594         Russia  Saint Petersburg  https://newsite.info/      MAIN
# 1370087         Russia  Saint Petersburg  https://newsite.info/      MAIN
# 1373161         Russia            Moscow  https://newsite.info/      MAIN
# 1373660         Russia  Saint Petersburg  https://newsite.info/      MAIN
#
#         slug  artificial  ...  messenger  device_category  mobile_phone  \
# 1359682  NaN           0  ...        NaN                2         apple
# 1368594  NaN           0  ...        NaN                2         apple
# 1370087  NaN           0  ...        NaN                2         apple
# 1373161  NaN           0  ...        NaN                2         apple
# 1373660  NaN           0  ...        NaN                2         apple
#
#          mobile_phone_model operating_system_root operating_system  \
# 1359682              iPhone            ios_double            ios18
# 1368594              iPhone            ios_double            ios18
# 1370087              iPhone            ios_double            ios18
# 1373161              iPhone            ios_double            ios18
# 1373660              iPhone            ios_double            ios18
#
#                browser browser_major_version screen_width screen_height
# 1359682  safari_mobile                     0            0             0
# 1368594  safari_mobile                     0            0             0
# 1370087  safari_mobile                     0            0             0
# 1373161  safari_mobile                     0            0             0
# 1373660  safari_mobile                     0            0             0
#
# [5 rows x 31 columns]

# %%
hits['date_time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#Remove bots
hits=hits[hits['artificial'] !=1]
hits
# Out:
#          project_id             watch_id           date_time  \
# 1359682           0  7974165888557582235 2025-04-11 08:53:37
# 1368594           0  5392466718857393154 2025-04-20 15:26:19
# 1370087           0  2717532802682868090 2025-04-22 10:17:55
# 1373161           0  6099345943357788389 2025-04-24 21:30:44
# 1373660           0  8410812400479315010 2025-04-25 13:13:32
# ...             ...                  ...                 ...
# 188711            1   273950850987111032 2022-02-27 12:00:42
# 198486            1  2803614796122257556 2022-03-07 21:45:08
# 198512            1  2639194616573389236 2022-03-07 22:40:09
# 13511             1  3584469310609592364 2021-11-29 18:05:37
# 39018             1  4533570255843633432 2021-12-13 08:11:06
#
#                    client_id region_country       region_city  \
# 1359682                    8         Russia        Domodedovo
# 1368594                    8         Russia  Saint Petersburg
# 1370087                    8         Russia  Saint Petersburg
# 1373161                    8         Russia            Moscow
# 1373660                    8         Russia  Saint Petersburg
# ...                      ...            ...               ...
# 188711   9999538392999757430         Russia           Podolsk
# 198486   9999538392999757430         Russia            Moscow
# 198512   9999538392999757430         Russia            Moscow
# 13511     999974113071232035         Russia            Vyazma
# 39018    9999784522413914842         Russia               Ufa
#
#                                                        url page_type  \
# 1359682                              https://newsite.info/      MAIN
# 1368594                              https://newsite.info/      MAIN
# 1370087                              https://newsite.info/      MAIN
# 1373161                              https://newsite.info/      MAIN
# 1373660                              https://newsite.info/      MAIN
# ...                                                    ...       ...
# 188711   https://oldsite.info/progulochnaya-kolyaska-yo...   PRODUCT
# 198486   https://oldsite.info/kolyaska-2-v-1-chicco-bes...   PRODUCT
# 198512   https://oldsite.info/kolyaska-2-v-1-chicco-bes...   PRODUCT
# 13511    https://oldsite.info/catalog?cm_id=48443574_40...  CATEGORY
# 39018    https://oldsite.info/kolyaska-progulochnaya-up...   PRODUCT
#
#                                                       slug  artificial  ...  \
# 1359682                                                NaN           0  ...
# 1368594                                                NaN           0  ...
# 1370087                                                NaN           0  ...
# 1373161                                                NaN           0  ...
# 1373660                                                NaN           0  ...
# ...                                                    ...         ...  ...
# 188711                progulochnaya-kolyaska-yoya-skillmax           0  ...
# 198486   kolyaska-2-v-1-chicco-best-friend-crossover-si...           0  ...
# 198512   kolyaska-2-v-1-chicco-best-friend-crossover-si...           0  ...
# 13511                                                 ROOT           0  ...
# 39018            kolyaska-progulochnaya-uppababy-cruz-2018           0  ...
#
#          messenger  device_category  mobile_phone  mobile_phone_model  \
# 1359682        NaN                2         apple              iPhone
# 1368594        NaN                2         apple              iPhone
# 1370087        NaN                2         apple              iPhone
# 1373161        NaN                2         apple              iPhone
# 1373660        NaN                2         apple              iPhone
# ...            ...              ...           ...                 ...
# 188711         NaN                2         apple              iPhone
# 198486         NaN                2         apple              iPhone
# 198512         NaN                2         apple              iPhone
# 13511          NaN                2         apple              iPhone
# 39018          NaN                2          oppo             RMX1921
#
#         operating_system_root operating_system        browser  \
# 1359682            ios_double            ios18  safari_mobile
# 1368594            ios_double            ios18  safari_mobile
# 1370087            ios_double            ios18  safari_mobile
# 1373161            ios_double            ios18  safari_mobile
# 1373660            ios_double            ios18  safari_mobile
# ...                       ...              ...            ...
# 188711             ios_double            ios14  safari_mobile
# 198486             ios_double            ios14  safari_mobile
# 198512             ios_double            ios14  safari_mobile
# 13511              ios_double            ios13  safari_mobile
# 39018                 android       android_11   chromemobile
#
#         browser_major_version screen_width screen_height
# 1359682                     0            0             0
# 1368594                     0            0             0
# 1370087                     0            0             0
# 1373161                     0            0             0
# 1373660                     0            0             0
# ...                       ...          ...           ...
# 188711                     14          414           896
# 198486                     14          414           896
# 198512                     14          414           896
# 13511                      13          320           568
# 39018                      96          360           780
#
# [166576 rows x 31 columns]

# %% [markdown]
# **Why? Bots create fake sessions → destroys sequence pattern**

# %%
#Keep only product pages
hits=hits[hits['page_type']=='product']

# %% [markdown]
# **Other pages = homepage, search, banners → NOT useful for next-product modeling**

# %% [markdown]
# **2 — Extract Product ID**

# %%
hits['product_id']=hits['slug'].astype(str)

# %%
hits
# Out:
# Empty DataFrame
# Columns: [project_id, watch_id, date_time, client_id, region_country, region_city, url, page_type, slug, artificial, is_page_view, not_bounce, link, download, last_traffic_source, last_search_engine_root, last_search_engine, last_adv_engine, last_social_network, last_social_network_profile, recommendation_system, messenger, device_category, mobile_phone, mobile_phone_model, operating_system_root, operating_system, browser, browser_major_version, screen_width, screen_height, product_id]
# Index: []
#
# [0 rows x 32 columns]

# %%
#Build Sequences
session_sequences = hits.groupby('client_id')['product_id'].apply(list)
